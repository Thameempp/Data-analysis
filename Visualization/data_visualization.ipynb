# %%
Matplotlib + Seaborn  (foundation)
Plotly               (interactive)
Streamlit            (deployment)

Matplotlib + Seaborn → learning, notebooks, research
Plotly + Streamlit → real-world projects
