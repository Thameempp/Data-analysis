# %% [markdown]
# # Matplotlib library
#
# - line plot , multiple line plot , and customization of line plot
# - Bar plot
# - Histograms
# - Scatter plot
# - Pie chart , with explode
# - Data Visualization with plots , and filter
# -

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# #   Line Plot

# %%
#  line styles : linestyle or 'colorTYPE' : linestyle='--'  , if color is red , then : 'r--'
#  types ;     '-', '--', ':', '-.'

# %%
# subplot :  row * column

# plt.subplot(2,2,n). -> 2×2 Grid (Most Common)
# plt.subplot(3,3,n). -> 3×3 Grid 
# plt.subplot(1,4,n). -> 1×4 (Horizontal Layout)
# plt.subplot(2,2,n). -> 4×1 (Vertical Layout)
# plt.subplot(2,2,n). -> 2×2 Grid (Most Common)

# fig → the overall figure object (the entire canvas)
# axes → a 2D array of Axes objects, shaped (2, 2)  :
    
# axes[0,0] → top-left
# axes[0,1] → top-right
# axes[1,0] → bottom-left
# axes[1,1] → bottom-right

# %%
# sample data 
p = [2,4,6,8,9]
q = [4,16,36,64,81]              # here p and q must have same dimension   

# creating a line plot
plt.plot(p,q)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
# creating a customized line plot

plt.plot(p,q, color='blue', linestyle='--', marker='o', linewidth=1, markersize=9)

# %%
# multiple plots 

x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]   # y = x^2
y2 = [1, 2, 3, 4, 5]     # y = x

plt.figure(figsize=(8,4))

plt.subplot(2,2,1)
plt.plot(x, y1, color='green')
plt.title("plot 1")            # parabolic

plt.subplot(2,2,2)
plt.plot(y1, x, color='red')
plt.title("plot 2")            # inverse of standard parabola. (horizontal).  x = y^2

plt.subplot(2,2,3)
plt.plot(x, y2, color='blue')
plt.title('plot 3')                 

plt.subplot(2,2,4)
plt.plot(y2, x, color='orange')
plt.title('plot 4')
# Out:
# Text(0.5, 1.0, 'plot 4')

# %%
plt.figure(figsize=(4,3))
plt.plot(x, y1, color='green', label='y = x^2', linestyle='--')
plt.plot(x, y2, color='red', label='y = x', linewidth=2)
plt.title('multiple line one plot')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(x, y1, 'r--', label='-- dashed')
plt.plot(x, y2, 'b:', label=': dotted')
# plt.plot(x, y3, 'g-.', label='-. dashdot')

plt.legend()
plt.title("Different Line Styles")
plt.grid(True)
plt.show()

# %%
# Line Transparency  example;    alpha= 0.1 (more trans..) ,  0.8 (less trans..)

# %%
plt.figure(figsize=(4,3))
plt.plot(x, y1, color='red', alpha=0.2, linewidth=8, label='Transparent')
plt.plot(x, y2, color='blue', alpha=0.8, linewidth=4, label='Less Transparent')

plt.legend()
plt.title("Line Transparency Example")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Step plot

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.step(x, y1, 'r--', linewidth=3)
plt.title('plot 1')
plt.xlabel('x')
plt.ylabel('y1')
plt.grid(True)


plt.subplot(1,3,2)
plt.step(x, y2, 'g:', linewidth=3)
plt.title('plot 2')
plt.xlabel('x')
plt.ylabel('y2')
plt.grid(True)


plt.subplot(1,3,3)
plt.step(y1, x, 'b-.', linewidth=3)
plt.title('plot 3')
plt.xlabel('y1')
plt.ylabel('x')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

fig, axes = plt.subplots(2, 2, figsize=(8,6))


axes[0,0].plot(x, y, color='red')
axes[0,0].set_title("Plot 1: y = x²")  # top left

axes[0,1].plot(y, x, color='blue')
axes[0,1].set_title("Plot 2: inverse parabola")  # top right

axes[1,0].plot(x, [i*2 for i in y], color='green')     # [i*2 for i in y] -> multiply each element in y with 2 , so y = 2 * x^2
axes[1,0].set_title("Plot 3: y = 2x² (scaled up)")  

axes[1,1].plot(y, [i/2 for i in x], color='purple')
axes[1,1].set_title("Plot 4: flattened inverse") 

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Filled area line plot

# %%
plt.plot(x, y1, color='green')
plt.fill_between(x, y1, color='lightgreen', alpha=0.4)
plt.title("Line Plot with Filled Area")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Line plot with Annotation

# %%
plt.plot(x, y1, color='blue', marker='o')
plt.title("Annotated")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Add a note at the max point
plt.annotate('Peak', xy=(3, 9), xytext=(2, 15),         # xytext=(2, 15) -> position of annoted word
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate('Minimum', xy=(1, 1), xytext=(1, 12),
             arrowprops=dict(facecolor='black', arrowstyle='->'))

plt.grid(True)
plt.show()

# %% [markdown]
# | Part                | Explanation                                       |
# | ------------------- | ------------------------------------------------- |
# | `'Peak'`            | Text that will appear on the chart                |
# | `xy=(3, 9)`         | **Exact data point** being highlighted (x=3, y=9) |
# | `xytext=(2, 15)`    | **Position where the text is displayed**          |
# | `arrowprops`        | Controls arrow appearance                         |
# | `facecolor='black'` | Arrow color                                       |
# | `arrowstyle='->'`   | Arrow shape                                       |

# %% [markdown]
# ## Bar plot

# %%
# plt.bar(x, height)

# %%
# vertical bar plot
categories = ['A', 'B', 'C']
values = [10, 15, 7]

plt.bar(categories, values)
plt.xlabel('categories')
plt.ylabel('values')
plt.title('Simple bar plot')
plt.show()

# %%
# horizontal bar plot
plt.barh(categories, values)
# Out:
# <BarContainer object of 3 artists>

# %%
# Grouped bar plot
# example 1
x = np.arange(len(categories))
width = 0.35
plt.bar(x-width/2, [10, 15, 7], width, label='2024')
plt.bar(x+width/2, [12, 18, 9],width, label='2025', color='black')
# Out:
# <BarContainer object of 3 artists>

# %%
# explanation of grouped bar plot
"""
x + width/2 → positions of the bars on the X-axis
[12, 18, 9] → Y-axis values (bar heights)
width → thickness of each bar
label='2025' → legend name
color='black' → bar color
"""

'''
x positions →   Jan     Feb     Mar
2024 bars  →   10      15      7
2025 bars  →   12      18      9
'''
# Out:
# '\nx positions →   Jan     Feb     Mar\n2024 bars  →   10      15      7\n2025 bars  →   12      18      9\n'

# %%
# example 2
products = ['Laptops','Mobile','Tablet']
sales_2023 = [45, 65, 30]
sales_2024 = [70, 95, 25]
# x position
x = np.arange(len(products))

# bar width
width = 0.35

# plotting grouped bars
plt.bar(x-width/2, sales_2023, width, label='2023', color='green')
plt.bar(x+width/2, sales_2024, width, label='2024',color='brown')

# label
plt.xlabel('products')
plt.ylabel('sales (in units)')
plt.title('Product sales comparison')
plt.xticks(x, products)
plt.legend()
plt.show()

# %% [markdown]
# ## Histogram

# %%
data = [5, 19, 35, 60, 65, 81, 75, 80, 85, 90]

plt.hist(data)
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title("Basic Histogram")
plt.show()

# %%
plt.hist(data, bins=5, edgecolor='black') # bins=5 → divides data into 5 ranges
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title("Histogram with Custom Bins")
plt.show()

# %% [markdown]
# #### Multiple Histograms (Comparison)

# %%
marks_2024 = [50, 55, 60, 65, 70, 75, 80]
marks_2025 = [55, 60, 65, 70, 75, 85, 90]

plt.hist(marks_2024, bins=5, alpha=0.6, label='2024')
plt.hist(marks_2025, bins=5, alpha=0.6, label='2025')

plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title("Marks Distribution Comparison")
plt.legend()
plt.show()

# %% [markdown]
# Advanced Histogram (Density + Range Control)

# %%
data = np.random.normal(70, 10, 1000)  # mean=70, std=10 # It generates 1000 random numbers that follow a normal (bell-shaped) distribution

# np.random.normal() → realistic data # np.random.normal() - Generates random values from a normal distribution
# Also called Gaussian distribution
# density=True → area under histogram = 1

plt.hist(data, bins=30, density=True, edgecolor='black')
plt.xlabel("Values")
plt.ylabel("Density")
plt.title("Advanced Histogram (Density)")
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
x = [1, 2, 3, 4, 5, 9, 7, 8]
y = [3, 4, 5, 16, 17, 18, 49, 64]

plt.scatter(x, y)

plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Basic Scatter Plot")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 15, 8, 20, 12]
sizes = [100, 200, 150, 300, 180]


plt.scatter(x, y, s=sizes, alpha=0.6)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scatter with Size")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)

colors = np.random.rand(50)

plt.scatter(x, y, c=colors, alpha=0.7)
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Advanced Scatter Plot")
plt.show()

# %% [markdown]
# ## Box plot

# %%
data = [45, 47, 49, 50, 55, 60, 65, 70, 75, 100]

plt.boxplot(data)
plt.title("Basic Box Plot")
plt.ylabel("Values")
plt.show()

# %%
# Box plot with multiple group
marks_A = [50, 55, 60, 65, 70]
marks_B = [45, 50, 55, 60, 90]

plt.boxplot([marks_A, marks_B], labels=['Class A', 'Class B'])
plt.title("Marks Comparison")
plt.ylabel("Marks")
plt.show()
# Out:
# /var/folders/d0/0z7mg03d4zggp6_2nq04bd280000gn/T/ipykernel_65758/581430561.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([marks_A, marks_B], labels=['Class A', 'Class B'])

# %%
# Horizontal box plot 
data = [45, 50, 55, 60, 65, 70, 75, 100]

plt.boxplot(data, vert=False)
plt.title("Horizontal Box Plot")
plt.xlabel("Values")
plt.show()

# %%
data = np.random.normal(70, 10, 100)

plt.boxplot(
    data,
    patch_artist=True,
    showfliers=True
)

plt.title("Advanced Box Plot")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ## Pie chart

# %%
sizes = [40, 30, 20, 10]
labels = ['A', 'B', 'C', 'D']

plt.pie(sizes, labels=labels)
plt.title("Basic Pie Chart")
plt.show()

# %%
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%', # shows percentage value on each slice # %1.1f -> one decimal place # %% -> display % symbol
    startangle=90 # not mendatory
)
plt.title("Pie Chart with Percentages")
plt.show()

# %%
# explode
explode = [0.1, 0, 0, 0]  # highlight first slice

plt.pie(
    sizes,
    labels=labels,
    explode=explode,
    autopct='%1.1f%%',
    shadow=True
)
plt.title("Exploded Pie Chart")
plt.show()

# %%
expl = [0.1, 0.3, 0.5, 0.2]
plt.pie(
    sizes,
    labels=labels,
    explode=expl,
    autopct='%1.0f%%',
    shadow=True
)
plt.title('practice explode')
plt.show()

# %%
# example
companies = ['Apple', 'Samsung', 'Xiaomi', 'Others']
market_share = [35, 30, 20, 15]

plt.pie(
    market_share,
    labels=companies,
    autopct='%1.0f%%',
    startangle=140
)
plt.title("Smartphone Market Share")
plt.show()

# %% [markdown]
# ## Area Plot / stack plot

# %%
# area plot : Filled version of a line plot , area plot shows how values change over time
x = [1, 2, 3, 4, 5]
y = [3, 5, 2, 6, 4]

plt.fill_between(x, y) # fill_between() fills area under the curve
plt.title("Simple Area Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Scenario: Daily website visitors over a week — showing trend + magnitude.

# X-axis (days)
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# Visitors count
visitors = [120, 150, 180, 170, 200, 220, 190]

plt.fill_between(days, visitors)

plt.title('Daily website visitors')
plt.xlabel('Day')
plt.ylabel('Number of visitors')
plt.show()

# %% [markdown]
# ### Stacked area plot

# %%
# stacked area plot : Multiple area plots stacked on top of each other, Shows part-to-whole over time
x = [2019, 2020, 2021, 2022, 2023]

product_A = [20, 25, 30, 35, 40]
product_B = [15, 20, 25, 30, 35]
product_C = [10, 15, 20, 25, 30]

plt.stackplot(
    x,
    product_A,
    product_B,
    product_C,
    labels=['A', 'B', 'C']
)

plt.legend(loc='upper left')
plt.title("Stacked Area Plot")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.show()

# %%
# Each layer = one category
# Total height = sum of all values

# plt.fill_between(x, y)   # area plot
# plt.stackplot(x, y1, y2, ...)  # stacked area plot

'''
| Area Plot      | Stacked Area Plot     |
| -------------- | --------------------- |
| Single dataset | Multiple datasets     |
| Trend emphasis | Contribution emphasis |
| Simple         | Comparative           |


'''

# An area plot shows magnitude over time by filling under a line, while a stacked area plot shows how multiple series contribute to a cumulative total using stackplot().
# Out:
# '\n| Area Plot      | Stacked Area Plot     |\n| -------------- | --------------------- |\n| Single dataset | Multiple datasets     |\n| Trend emphasis | Contribution emphasis |\n| Simple         | Comparative           |\n\n\n'

# %%
# Scenario: Monthly energy consumption from different sources contributing to the total.
# X-axis (months)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']

# Energy sources
solar = [20, 25, 30, 35, 40, 45]
wind  = [15, 18, 20, 22, 25, 28]
coal  = [40, 38, 35, 30, 25, 20]

plt.stackplot(
    months,
    solar,
    wind,
    coal,
    labels=['solar', 'wind', 'coal']
)

plt.legend(loc='upper left')
plt.title('Monthly energy consumption by source')
plt.xlabel('Month')
plt.ylabel('Energy unit')
plt.show()

# %% [markdown]
# ## Vector & Field Plots

# %%
# Vector: A quantity with magnitude + direction
# Vector / Field Plot: Shows vectors at many points in space
# Each arrow represents: Direction → arrow orientation, Magnitude → arrow length

# Basic Vector Plot

x = [0, 1, 2] # starting points
y = [0, 1, 2]

u = [1, 1, 1]   # x-direction
v = [0, 1, 2]   # y-direction

plt.quiver(x, y, u, v)
plt.title("Basic Vector Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Vector Field
# use : Flow or force field visualization


x, y = np.meshgrid(np.arange(-2, 3), np.arange(-2, 3))
u = -y
v = x
# np.arange(-2, 3) : Generates numbers from −2 to +2
# np.meshgrid(...) : Converts 1D arrays into 2D coordinate grids x grid and y grid
# Each (x[i][j], y[i][j]) is a point in 2D space

# u → x-direction component of vector ,  v → y-direction component of vector

plt.quiver(x, y, u, v)
plt.title("Vector Field")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# real-world use of vector field plots :

# Rotational motion
# Fluid flow
# Magnetic fields
# Gradient visualization (ML)

# %%
# Create grid points
x, y = np.meshgrid(
    np.arange(-3, 4),  # arange(x, y) means : x, x+1, x+2, ..., y-1 , so , here -3,-2,-1,0,1,2,3
    np.arange(-3, 4)
)

# Define vector components (radial field)
u = x
v = y

# Plot vector field
plt.quiver(x, y, u, v)
plt.title("Radial Vector Field")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()


# Electric field of a positive charge
# Explosion / expansion model

# %% [markdown]
# | Location   | Arrow Direction |
# | ---------- | --------------- |
# | Near (0,0) | Very small      |
# | (+x,+y)    | Up-right        |
# | (−x,+y)    | Up-left         |
# | (+x,−y)    | Down-right      |
# | (−x,−y)    | Down-left       |

# %% [markdown]
# ## 3D plots

# %%
# for 3d plot , we need to import : from mpl_toolkits.mplot3d import Axes3D  this also
from mpl_toolkits.mplot3d import Axes3D

x = [1, 2, 3, 4]
y = [2, 3, 4, 5]
z = [3, 5, 7, 9]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z)
ax.set_title("3D Scatter Plot")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

plt.show()

# %%
# 3d line plot 
t = np.linspace(0, 10, 100)
x = t
y = t**2
z = t**3

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(x, y, z)
ax.set_title("3D Line Plot")

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
# 3d surface plot
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
x, y = np.meshgrid(x, y)
z = x**2 + y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(x, y, z)
ax.set_title("3D Surface Plot")

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_wireframe(x, y, z)
ax.set_title("3D Wireframe Plot")

plt.show()

# %%
# Points → scatter
# Path   → line
# Sheet  → surface
# Mesh   → wireframe

# %%
# 3d bar plot
