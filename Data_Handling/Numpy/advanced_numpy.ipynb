# %% [markdown]
# # advaced numpy topics
# ### Numpy array vs Python lists
# ### Advanced Indexing
# ### Broadcasting
# ### Broadcasting Rules
# ### Working with mathematical formulas
# ### Working with missing values
# ### Plotting Graphs
# ### Meshgrids
