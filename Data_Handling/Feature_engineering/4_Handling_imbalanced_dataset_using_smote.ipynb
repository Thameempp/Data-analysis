# %% [markdown]
# ### Handling imbalanced dataset using smote
# #### what is smote :
#
# - SMOTE (Synthetic Minority Over-sampling Technique) is a method that balances an imbalanced dataset by creating new synthetic samples for the minority class instead of duplicating existing ones.
#
# ##### in short :
# - SMOTE balances classes by generating synthetic minority data points using nearest neighbors.
